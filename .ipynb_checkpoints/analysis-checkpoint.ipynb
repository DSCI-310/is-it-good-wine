# %%
from IPython import display

# %%
# %pip install numpy

# %% [markdown]
# # Alcohol Non-Anonymous: What chemical ingredients contribute to better rated wine?

# %%
display.Image("wine-header.jpg")

# %% [markdown]
# **Objective**: We want to be able to classify unseen wines as good/bad using a LogisticRegression model on our quantitative variables.

# %% [markdown]
# ### Importing required packages

# %%
import altair as alt
import numpy as np
import pandas as pd

from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %% [markdown]
# ### Preliminary EDA

# %%
df = pd.read_csv('winequality-red.csv', sep=',') # UCI Machine Learning Database

# %%
x = alt.Chart(df).mark_bar().encode(
    alt.X('quality:O'),
    alt.Y(alt.repeat("row"), type='quantitative')
).properties(
    width=200,
    height=100
).repeat(
    row=['alcohol'])

x
# Out:
# /Users/justin/miniforge3/lib/python3.10/site-packages/altair/utils/core.py:283: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.RepeatChart(...)

# %%
cor_data = (df.corr()
            .stack()
            .reset_index()     # The stacking results in an index on the correlation values, we need the index as normal columns for Altair
            .rename(columns={0: 'correlation', 'level_0': 'variable1', 'level_1': 'variable2'}))
cor_data['correlation_label'] = cor_data['correlation'].map('{:.2f}'.format)  # Round to 2 decimal

# %%
alt.Chart(cor_data).mark_rect().encode(
    alt.X('variable1:O'),
    alt.Y('variable2:O'),
    alt.Color('correlation'),
    alt.Tooltip(['correlation_label']),
).interactive().properties(width=300, height=300)
# Out:
# /Users/justin/miniforge3/lib/python3.10/site-packages/altair/utils/core.py:283: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# ### Building the model

# %% [markdown]
# Building the classification model using LogisticRegression()

# %%
train_df, test_df = train_test_split(df, test_size=0.10, random_state=123)
train_df['target'] = np.where(train_df['quality'] >= 5, 1, 0)
test_df['target'] = np.where(test_df['quality'] >= 5, 1, 0)
train_df.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1572            7.3             0.690         0.32             2.2      0.069
# 318             9.8             0.660         0.39             3.2      0.083
# 336             8.9             0.430         0.45             1.9      0.052
# 777             6.9             0.635         0.17             2.4      0.241
# 1318            7.5             0.630         0.27             2.0      0.083
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1572                 35.0                 104.0  0.99632  3.33       0.51
# 318                  21.0                  59.0  0.99890  3.37       0.71
# 336                   6.0                  16.0  0.99480  3.35       0.70
# 777                   6.0                  18.0  0.99610  3.40       0.59
# 1318                 17.0                  91.0  0.99616  3.26       0.58
#
#       alcohol  quality  target
# 1572      9.5        5       0
# 318      11.5        7       1
# 336      12.5        6       0
# 777      10.3        6       0
# 1318      9.8        6       0

# %%
# Checking for class imbalance
train_df["target"].value_counts()
# Out:
# 0    1247
# 1     192
# Name: target, dtype: int64

# %%
# Splitting into X and y train and test sets
X_train = train_df.drop(columns=["target", "quality"])
y_train = train_df["target"]

X_test = test_df.drop(columns=["target", "quality"])
y_test = test_df["target"]

# %% [markdown]
# #### Hyperparameter Optimization

# %%
scores_dict = {
    "C": 10.0 ** np.arange(-4, 6, 1),
    "mean_train_scores": list(),
    "mean_cv_scores": list(),
}
for C in scores_dict["C"]:
    pipe = make_pipeline(StandardScaler(), LogisticRegression(C = C))
    scores = cross_validate(pipe, X_train, y_train, return_train_score=True)
    scores_dict["mean_train_scores"].append(scores["train_score"].mean())
    scores_dict["mean_cv_scores"].append(scores["test_score"].mean())

results_df = pd.DataFrame(scores_dict)
results_df
# Out:
#              C  mean_train_scores  mean_cv_scores
# 0       0.0001           0.866574        0.866575
# 1       0.0010           0.866574        0.866575
# 2       0.0100           0.869353        0.869348
# 3       0.1000           0.884642        0.881860
# 4       1.0000           0.884294        0.879776
# 5      10.0000           0.884120        0.880468
# 6     100.0000           0.884120        0.880468
# 7    1000.0000           0.884120        0.880468
# 8   10000.0000           0.884120        0.880468
# 9  100000.0000           0.884120        0.880468

# %% [markdown]
# #### Applying the LogisticRegression Classifier

# %%
# Scaling and applying LogisticRegression model to our data
pipe = make_pipeline(StandardScaler(), LogisticRegression(C = 0.1))
pipe.fit(X_train, y_train)

# Printing out coefficients of the regression model for values influencing the model.
flatten = pipe.named_steps["logisticregression"].coef_ # 2-D Array
flatten = flatten.flatten() # Converting 2-D Array to 1-D Array

coeffs = pd.DataFrame(
    data={
        "features": X_train.columns, # 1-D Array
        "coefficients": flatten, # 1-D Array
    })

intercept = pipe.named_steps["logisticregression"].intercept_

print(coeffs.sort_values('coefficients', ascending = False))
print(f"The intercept is: {intercept}")
# Out:
#                 features  coefficients
# 10               alcohol      0.771653
# 9              sulphates      0.551729
# 0          fixed acidity      0.276676
# 3         residual sugar      0.222747
# 2            citric acid      0.183559
# 8                     pH      0.008501
# 5    free sulfur dioxide     -0.016089
# 7                density     -0.334120
# 4              chlorides     -0.360716
# 1       volatile acidity     -0.443586
# 6   total sulfur dioxide     -0.511957
# The intercept is: [-2.71778144]

# %%
scores = cross_validate(pipe, X_train, y_train, return_train_score=True)

pd.DataFrame(scores)
# Out:
#    fit_time  score_time  test_score  train_score
# 0  0.020972    0.002147    0.861111     0.888792
# 1  0.003369    0.000608    0.892361     0.882711
# 2  0.003332    0.000570    0.881944     0.886186
# 3  0.007349    0.002006    0.895833     0.879235
# 4  0.007834    0.001764    0.878049     0.886285

# %%
# Let's try categorizing a random wine sample!
pipe.score(X_test, y_test) * 100
# Out:
# 85.625

# %%
ax = pd.DataFrame(data = {'actual': y_test,
                          'predicted': pipe.predict(X_test)})
ax['correct'] = ax['actual'] == ax['predicted']
ax.correct.value_counts()
# Out:
# True     137
# False     23
# Name: correct, dtype: int64

# %% [markdown]
# ### Analysis

# %% [markdown]
# I plan on plotting the scatter plots of each variable in a facet to compare the variables that affect quality the most. We can maybe try SVM (R/C) RBF too?
